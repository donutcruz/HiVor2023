# %% [markdown]
# # Heimadæmi 08| TÖL203G
# #### Donn Eunice Bartido Patambag | 2507943479 | deb5@hi

# %% [markdown]
# ## [Línuleg Könnun ]
# ![image.png](attachment:68f184a3-fb95-420e-8a28-a006cb0a8dff.png)

# %% [markdown]
# ### Lausn 1.
#
# ![image.png](attachment:4b69ded3-da99-423d-b1c6-c96271335185.png)
#
# ![image.png](attachment:4cf921a3-17ef-48ab-8bf5-d5fe6a96a7e5.png)
# ![image.png](attachment:3050f604-f605-456f-ad08-8c969f6e7709.png)
# ![image.png](attachment:451e13e9-4b96-4754-bd3f-4ad6bf043fdd.png)

# %% [markdown]
# ## 2. [Línuleg könnun]
#
# ![image.png](attachment:527a4836-2152-4563-b696-d81072be40c4.png)

# %% [markdown]
# ### Lausn 2.
#
# ![image.png](attachment:043effe0-0f9d-4391-9d33-6fa712e5b928.png)

# %% [markdown]
# ### 3.[Línuleg könnun]
#
# ![image.png](attachment:4d790197-e44c-4c2c-b3e1-c9bb57d1eaec.png)

# %% [markdown]
# ### Kóða fyrir nýju aðferðir
#
# - **capacity()**
#
# ![image.png](attachment:543fa8ff-78d6-4f5a-99d2-8ed3a86a9996.png)
#
# - **longestCluster()**
#
# ![image.png](attachment:87a0ccf7-fcc5-4ebf-b056-e3383b4a3ed0.png)
#
# - **size()**
#
# ![image.png](attachment:7bb1d5da-6b38-4531-bd60-dd0becec941f.png)

# %% [markdown]
# ### Skjáskót af keyrslu
# ![image.png](attachment:48f719d3-739e-45dd-890a-3ba8f79548ce.png)

# %% [markdown]
# ## 4. [Táknatöflur]
# ![image.png](attachment:e7c671b4-3736-427d-bdf0-daca2ba98b83.png)

# %% [markdown]
# ### Lausn 4.

# %% [markdown]
# ####  Tímamælinganna á innsetningu orðanna í „War and Peace“ í þessar fjórar gagnagrindur
# - **Insertion**
#     - BST Insertion Time: 308 ms
#     - RedBlackBST Insertion Time: 302 ms
#     - SeparateChainingHashST Insertion Time: 181 ms
#     - LinearProbingHashST Insertion Time: 74 ms

# %% [markdown]
# ####  Tímamælinganna á innsetningu orðanna í „Tale of Two Cities“ í þessar fjórar gagnagrindur
# - **Insertion**
#     - BST Insertion Time: 91 ms
#     - RedBlackBST Insertion Time: 114 ms
#     - SeparateChainingHashST Insertion Time: 67 ms
#     - LinearProbingHashST Insertion Time: 34 ms

# %% [markdown]
# ## 5.[Tákntöflur]

# %% [markdown]
# ### Lausn 5.
#
# #### Forritið
#
# import java.util.ArrayList;
# import java.util.List;
#
# public class daemi5 {
#
#     public static List<String> generateStrings(int n) {
#         List<String> firstSet = generateStrings(n, 'a');
#         List<String> secondSet = generateStrings(n, 'b');
#
#         // Sameina báða listana af strengjum
#         firstSet.addAll(secondSet);
#
#         return firstSet;
#     }
#
#     private static List<String> generateStrings(int n, char base) {
#         // Base case
#         if (n == 0) {
#             List<String> list = new ArrayList<>();
#             list.add("");
#             return list;
#         }
#
#         // Endurkvæmni
#         List<String> subList = generateStrings(n - 1, base);
#         List<String> list = new ArrayList<>();
#
#         // Búa til 2N strengi út frá subList með öfugum stafasetti
#         for (String s : subList) {
#             String reversed = new StringBuilder(s).reverse().toString();
#             list.add(base + s + base);
#             list.add(base + reversed + base);
#         }
#
#         return list;
#     }
#
#     public static void main(String[] args) {
#         int n = 4;
#         List<String> strings = generateStrings(n);
#
#         System.out.println("Hash gildi: " + strings.get(0).hashCode());
#         for (String s : strings) {
#             System.out.println(s);
#         }
#     }
# }
#
#
#
# #### Keyrsla á forrit
#
# ![image.png](attachment:76112a24-b243-4aff-b03c-a0dd6ada92be.png)
