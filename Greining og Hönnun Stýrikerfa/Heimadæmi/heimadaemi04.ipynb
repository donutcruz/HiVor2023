# %% [markdown]
# # Heimadæmi04  Greining og Hönnun stýrikerfa TÖV201G
# ### Donn Eunice Bartdo deb5@hi.is
# Skil 28.feb 2023

# %% [markdown]
# ## 4.2 Obtain the simplified Boolean expression
#
# Obtain the simplified boolean expression for output F and G in terrms of the input variables in the circuit of Fig P4.2
# ![Screenshot 2023-02-22 at 18.13.44.png](attachment:e945b461-7c05-42fb-adff-e0a1122996c2.png)

# %% [markdown]
# ### Lausn 4.2
#
# - **F =** (A + D)(A' + BC) = A'D + ABC
# - **G =** (A + D')(A' + BC) = A'D' + ABC + BCD' = A'D' + ABC
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# - **F =** A'D + ABC + BCD = A'D + ABC
# - **G =** (A + D)(A' + BC) = A'D' + ABC

# %% [markdown]
# ## 4.13 Adder-subtractor circiut
#
# The Adder-sub of circuit Fig.4.13 has the following values for mode inout M and data inputs A and B.
#
# ![Screenshot 2023-02-22 at 19.09.30.png](attachment:68bed689-f67c-4248-918a-95e1b5d2ba43.png)
#
# In each case, **determine** the values of the four **SUM**, the **carry C** and the **overflow V**.

# %% [markdown]
# ### Lausn 4.13
#
# ![Screenshot 2023-02-22 at 19.11.19.png](attachment:9c521c8b-e6d7-4344-943a-83c7a9cce27d.png)
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## 4.26 Construct
# Construct a 4-to-16-line code with five 2-to-4 decoders with enable

# %% [markdown]
# ### Lausn 4.26
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## 4.28 decoder, external gates - design combinational circuit
#
# - Using the decoder and external gates, design the combinational circuit defined by the following three Boolean functions
#
# ![Screenshot 2023-02-22 at 19.16.04.png](attachment:316753c7-afda-4319-b8b5-989ead7dfe4e.png)

# %% [markdown]
# ### Lausn 4.28
#
# - A)
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# - B)
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## 4.A0
#
# ![Screenshot 2023-02-22 at 19.18.14.png](attachment:d56450ed-2dfd-46a9-94cb-480433a08a49.png)

# %% [markdown]
# ### Lausn 4.A0
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## 4.A1
# ![Screenshot 2023-02-22 at 19.19.06.png](attachment:08e6f58b-5f41-4692-b41a-fabcd5c2044c.png)
