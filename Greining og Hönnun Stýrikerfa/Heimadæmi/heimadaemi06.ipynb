# %% [markdown]
# # Heimadæmi05  Greining og Hönnun stýrikerfa TÖV201G
# ### Donn Eunice Bartido deb5@hi.is
# Mars 2023

# %% [markdown]
# ## 6.4
#
# ![image.png](attachment:ce34b996-c3f1-4a86-9971-fec2f24f995c.png)

# %% [markdown]
# ### 6.4 Lausn
#
# - 101101 -> 1101; 0110; 1011; 1101; 0110; 1011

# %% [markdown]
# ## 6.11
#
# ![image.png](attachment:6914f988-d7f0-4ec6-b202-24802464880c.png)

# %% [markdown]
# ### 6.11 lausn
#
# - a) A count down counter
#
# - b) A count up counter

# %% [markdown]
# ## 6.14
# ![image.png](attachment:684d9e3c-0515-4451-a1c9-c98a06c69d56.png)
#
# <br>
# <br>
# <br>

# %% [markdown]
# ### 6.14 Lausn
#
# - a) * 1001100111 = **4;**
# - b) 1111000111 = **9;**
# - c) 0000001111 = **10**

# %% [markdown]
# ## 6.19
#
# ![image.png](attachment:9ec1d518-a5fe-477f-91c6-0d9e6a4d2cb4.png)

# %% [markdown]
# ### 6.19 Lausn
#
# - a) JK flip-flops
#
# ![image.png](attachment:8304a5fe-6c7d-410d-aa67-3f63b482f663.png)
#
# - b) D flip-flop
#
# ![Screenshot 2023-03-24 at 15.02.14.png](attachment:e606321b-c91e-4f32-97cb-7981d08919ba.png)
#
# ![Screenshot 2023-03-24 at 15.02.38.png](attachment:a3f5590a-d6f4-4c12-b2e5-6aa750dccd2f.png)
#
# - c) Determine the most effictive of the three designs
#
# ![image.png](attachment:628c1911-df8d-4276-9484-cefe5de38f0a.png)

# %% [markdown]
# ## 6.A0
#
# ![Screenshot 2023-03-23 at 00.27.08.png](attachment:88fc4602-f906-45b1-8bf9-030bbd2ba903.png)

# %% [markdown]
# ### 6.A0 Lausn

# %% [markdown]
# - Step 1/2
#
# To implement the binary counter in sync with the given sequence of numbers, you need a 4-D flip-flop because you need to count up to 14 (which requires 4 bits).
#
# **The binary equivalent of the sequence is**
# - 0000
# - 0010
# - 0100
# - 0110
# - 1000
# - 1010
# - 1100
# - 1110
#
# **Explanation:**
#
# To change from 14 to 9, we have to reset the first and second bits and increment the third bit. The fourth bit stays the same. Binary equal to 9 is 1001, so the next state after 1110 (14) should be 1001 (9).
#
# The output **Y should be 1 when** the counter is at 6 (0110) and 12 (1100). Therefore, we can use an **AND gate** with inputs from the third and fourth flip-flops to generate the output.
#
# **Explanation:**
#
# Where (Q3,Q2,Q1,Q0) is the current state, (Q3,Q2,Q1,Q0)' is the next state, 1 is the time pulse, and Y is the output.
#
# ![Screenshot 2023-03-27 at 13.19.51.png](attachment:19fb458d-e625-4b38-8daf-4f979df1702f.png)
#
# **Explanation:**
# The current state is represented by D flip-flops and the next state is generated by a combinational circuit based on the current state and the input.
#
# To implement the circuit, we can use four D flip-flops connected as a binary counter and a 4-input AND gate to produce the Y output. We also need a 2-input MUX to select the next state based on the registration.
